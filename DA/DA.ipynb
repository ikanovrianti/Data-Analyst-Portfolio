# %% [markdown]
# # Tentang Dataset

# %% [markdown]
# ### Data Memiliki beberapa Column, yaitu :
# #### 1. Salary Estimate
# #### 2. Location
# #### 3. Company Rating
# #### 4. Job Description and more.

# %% [markdown]
# # Import Dataset

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import pandasql as ps 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Mempersiapkan Data
# ### Import Dataset

# %%
data = pd.read_csv('DataAnalyst.csv')
data.head()
# Out:
#    Unnamed: 0                                          Job Title  \
# 0           0  Data Analyst, Center on Immigration and Justic...
# 1           1                               Quality Data Analyst
# 2           2  Senior Data Analyst, Insights & Analytics Team...
# 3           3                                       Data Analyst
# 4           4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue Competitors Easy Apply
# 0  $100 to $500 million (USD)          -1       True
# 1      $2 to $5 billion (USD)          -1         -1
# 2    Unknown / Non-Applicable     GoDaddy         -1
# 3   $50 to $100 million (USD)          -1         -1
# 4  $100 to $500 million (USD)  DraftKings       True

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 281.8+ KB

# %% [markdown]
# ### Hapus Column yang tidak penting

# %%
data = data.drop(["Unnamed: 0", "Competitors", "Easy Apply"], axis =1)

# %%
data.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size  Founded               Type of ownership  \
# 0    201 to 500 employees     1961          Nonprofit Organization
# 1        10000+ employees     1893          Nonprofit Organization
# 2  1001 to 5000 employees     2003               Company - Private
# 3    201 to 500 employees     2002  Subsidiary or Business Segment
# 4   501 to 1000 employees     2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue
# 0  $100 to $500 million (USD)
# 1      $2 to $5 billion (USD)
# 2    Unknown / Non-Applicable
# 3   $50 to $100 million (USD)
# 4  $100 to $500 million (USD)

# %% [markdown]
# ### Mencari Data NULL

# %%
print(data.isnull().any()) #jika terdapat data berisi NULL maka hasilnya ada yg "True"
# Out:
# Job Title            False
# Salary Estimate      False
# Job Description      False
# Rating               False
# Company Name          True
# Location             False
# Headquarters         False
# Size                 False
# Founded              False
# Type of ownership    False
# Industry             False
# Sector               False
# Revenue              False
# dtype: bool

# %% [markdown]
# ### Menghapus Data NULL

# %%
data = data.dropna()
data.where(data == '-1')
data
# Out:
#                                               Job Title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2248  RQS - IHHA - 201900004460 -1q Data Security An...
# 2249              Senior Data Analyst (Corporate Audit)
# 2250  Technical Business Analyst (SQL, Data analytic...
# 2251                Data Analyst 3, Customer Experience
# 2252                        Senior Quality Data Analyst
#
#                   Salary Estimate  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 2248  $78K-$104K (Glassdoor est.)
# 2249  $78K-$104K (Glassdoor est.)
# 2250  $78K-$104K (Glassdoor est.)
# 2251  $78K-$104K (Glassdoor est.)
# 2252  $78K-$104K (Glassdoor est.)
#
#                                         Job Description  Rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# 3     Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4     ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
# ...                                                 ...     ...
# 2248  Maintains systems to protect data from unautho...     2.5
# 2249  Position:\nSenior Data Analyst (Corporate Audi...     2.9
# 2250  Title: Technical Business Analyst (SQL, Data a...    -1.0
# 2251  Summary\n\nResponsible for working cross-funct...     3.1
# 2252  You.\n\nYou bring your body, mind, heart and s...     3.4
#
#                                  Company Name        Location  \
# 0              Vera Institute of Justice\n3.2    New York, NY
# 1     Visiting Nurse Service of New York\n3.8    New York, NY
# 2                            Squarespace\n3.4    New York, NY
# 3                               Celerity\n4.1    New York, NY
# 4                                FanDuel\n3.9    New York, NY
# ...                                       ...             ...
# 2248                       Avacend, Inc.\n2.5      Denver, CO
# 2249                   Arrow Electronics\n2.9  Centennial, CO
# 2250                                 Spiceorb      Denver, CO
# 2251         Contingent Network Services\n3.1  Centennial, CO
# 2252                          SCL Health\n3.4  Broomfield, CO
#
#           Headquarters                    Size  Founded  \
# 0         New York, NY    201 to 500 employees     1961
# 1         New York, NY        10000+ employees     1893
# 2         New York, NY  1001 to 5000 employees     2003
# 3           McLean, VA    201 to 500 employees     2002
# 4         New York, NY   501 to 1000 employees     2009
# ...                ...                     ...      ...
# 2248    Alpharetta, GA     51 to 200 employees       -1
# 2249    Centennial, CO        10000+ employees     1935
# 2250                -1                      -1       -1
# 2251  West Chester, OH    201 to 500 employees     1984
# 2252    Broomfield, CO        10000+ employees     1864
#
#                    Type of ownership                                 Industry  \
# 0             Nonprofit Organization                        Social Assistance
# 1             Nonprofit Organization         Health Care Services & Hospitals
# 2                  Company - Private                                 Internet
# 3     Subsidiary or Business Segment                              IT Services
# 4                  Company - Private                      Sports & Recreation
# ...                              ...                                      ...
# 2248               Company - Private                   Staffing & Outsourcing
# 2249                Company - Public                                Wholesale
# 2250                              -1                                       -1
# 2251               Company - Private  Enterprise Software & Network Solutions
# 2252          Nonprofit Organization         Health Care Services & Hospitals
#
#                                 Sector                     Revenue
# 0                           Non-Profit  $100 to $500 million (USD)
# 1                          Health Care      $2 to $5 billion (USD)
# 2               Information Technology    Unknown / Non-Applicable
# 3               Information Technology   $50 to $100 million (USD)
# 4     Arts, Entertainment & Recreation  $100 to $500 million (USD)
# ...                                ...                         ...
# 2248                 Business Services    Unknown / Non-Applicable
# 2249                 Business Services          $10+ billion (USD)
# 2250                                -1                          -1
# 2251            Information Technology    $25 to $50 million (USD)
# 2252                       Health Care      $2 to $5 billion (USD)
#
# [2252 rows x 13 columns]

# %% [markdown]
# ### Terdapat beberapa Nilai "-1" pada Data. Untuk memperbaikinya, ganti nilai "-1" dengan "NA"

# %%
data = data.replace(to_replace = [-1, "-1"], value = "NA")
data.columns = data.columns.str.replace(' ', '_')
data = data[data.Sector != "NA"] #exclude all NA rows within "Sector" column
data.head()
# Out:
#                                            Job_Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary_Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job_Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company_Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size Founded               Type_of_ownership  \
# 0    201 to 500 employees    1961          Nonprofit Organization
# 1        10000+ employees    1893          Nonprofit Organization
# 2  1001 to 5000 employees    2003               Company - Private
# 3    201 to 500 employees    2002  Subsidiary or Business Segment
# 4   501 to 1000 employees    2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue  MinSalary  MaxSalary  AvgSalary
# 0  $100 to $500 million (USD)       37.0       37.0       37.0
# 1      $2 to $5 billion (USD)       37.0       37.0       37.0
# 2    Unknown / Non-Applicable       37.0       37.0       37.0
# 3   $50 to $100 million (USD)       37.0       37.0       37.0
# 4  $100 to $500 million (USD)       37.0       37.0       37.0

# %%
salary_estimate_adjustment = data['Salary_Estimate'].str.split('-', expand = True) #split numeric value
data['MinSalary'] = pd.to_numeric(salary_estimate_adjustment[0].str.extract('(\d+)', expand = False)) #buat column MinSalary berdasarkan kolom Salary_Estimate
data['MaxSalary'] = pd.to_numeric(salary_estimate_adjustment[0].str.extract('(\d+)', expand = False))
data.head()
# Out:
#                                            Job_Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary_Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
# 3  $37K-$66K (Glassdoor est.)
# 4  $37K-$66K (Glassdoor est.)
#
#                                      Job_Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
# 3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
# 4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                               Company_Name      Location  Headquarters  \
# 0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
# 2                         Squarespace\n3.4  New York, NY  New York, NY
# 3                            Celerity\n4.1  New York, NY    McLean, VA
# 4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                      Size Founded               Type_of_ownership  \
# 0    201 to 500 employees    1961          Nonprofit Organization
# 1        10000+ employees    1893          Nonprofit Organization
# 2  1001 to 5000 employees    2003               Company - Private
# 3    201 to 500 employees    2002  Subsidiary or Business Segment
# 4   501 to 1000 employees    2009               Company - Private
#
#                            Industry                            Sector  \
# 0                 Social Assistance                        Non-Profit
# 1  Health Care Services & Hospitals                       Health Care
# 2                          Internet            Information Technology
# 3                       IT Services            Information Technology
# 4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                       Revenue  MinSalary  MaxSalary  AvgSalary
# 0  $100 to $500 million (USD)       37.0       37.0       37.0
# 1      $2 to $5 billion (USD)       37.0       37.0       37.0
# 2    Unknown / Non-Applicable       37.0       37.0       37.0
# 3   $50 to $100 million (USD)       37.0       37.0       37.0
# 4  $100 to $500 million (USD)       37.0       37.0       37.0

# %% [markdown]
# ### Membuat Visualisasi Data

# %% [markdown]
# #### 1. Mencari Top 20 Bidang Pekerjaan yang paling banyak di Data Analyst

# %%
data['Job_Title'].value_counts()[:20]
# Out:
# Data Analyst               333
# Senior Data Analyst         77
# Junior Data Analyst         30
# Business Data Analyst       25
# Data Analyst Junior         17
# Data Quality Analyst        17
# Sr. Data Analyst            17
# Data Analyst II             14
# Lead Data Analyst           13
# Data Governance Analyst     13
# Data Reporting Analyst      12
# Data Analyst I              10
# Data Analyst III            10
# Sr Data Analyst              9
# Financial Data Analyst       9
# SQL Data Analyst             7
# Marketing Data Analyst       7
# Data Management Analyst      7
# Data Security Analyst        6
# Data Warehouse Analyst       6
# Name: Job_Title, dtype: int64

# %%
plt.figure(figsize=(15,7.5))

color_blind_palette = ["#DC267F", "#785EF0", "#648FFF", "#FE6100", "#FFB000", "#E80E8D", "#2E8766", "#95ABAC", "#65B925", "#906A42", "#C4D537", "#344A52", "#6C6E06", "#1C4DD2", "#216E00", "#2E03E5", "#A94424", "#7F6EA9", "#9B8453", "#380721"]

da_terbanyak = sns.barplot(x=data['Job_Title'].value_counts().head(20).index,
                                      y=data['Job_Title'].value_counts().head(20).values, palette=color_blind_palette)

plt.xticks(rotation='vertical')
plt.xlabel('Job_Title', fontsize=12.5)
plt.ylabel('Count', rotation=0, ha='right', fontsize=12.5)
plt.figtext(.5,.9,"Top 20 Bidang Pekerjaan yang paling banyak di DA", fontsize=20, fontweight='bold', fontname='helvetica', ha='center') #formatted title

for patch in da_terbanyak.patches:
             da_terbanyak.annotate("%.0f" % patch.get_height(), (patch.get_x() + patch.get_width() / 2., patch.get_height()),
                 ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                 textcoords='offset points')
plt.show()

# %% [markdown]
# ### 2. Mencari TOP 20 Pekerjaan dengan gaji tertinggi pada perusahaan dengan peringkat teratas

# %%
df_highest_salary_top_comp = """SELECT Job_Title, Company_Name, Sector,
                                    MAX(MaxSalary), MAX(Rating)
                                    FROM data
                                    GROUP BY Job_Title
                                    ORDER BY MaxSalary DESC, Rating DESC
                                    LIMIT 20"""
ps.sqldf(df_highest_salary_top_comp)
# Out:
#                                           Job_Title  \
# 0   Sr Digital Marketing Data Analyst (PAID SOCIAL)
# 1                          LIMS Master Data Analyst
# 2                     Data Analyst - Health, Senior
# 3                    Analyst, Financial Master Data
# 4                      Sr. Data Analyst — US Safety
# 5      QM DATA ANALYST II, WHITTIER, FULL TIME DAYS
# 6                Data Analyst - Marketing Analytics
# 7                      Senior Clinical Data Analyst
# 8         19-0574 - Service Operations Data Analyst
# 9                            Copyright Data Analyst
# 10                     Music Copyright Data Analyst
# 11                        Data Analyst-HEDIS & Star
# 12                                 Sr Analyst, Data
# 13                      Sr. Data Analyst (Pharmacy)
# 14                         Data Analyst *Temp-Hire*
# 15                           Discovery Data Analyst
# 16                          System and Data Analyst
# 17         Data Entry Clerk and Analyst - Financial
# 18                         AI Insights Data Analyst
# 19                           Senior HR Data Analyst
#
#                                          Company_Name  \
# 0                            LaBine & Associates\n5.0
# 1                             USDM Life Sciences\n4.6
# 2                      Blue Shield of California\n4.1
# 3                     Warner Bros. Entertainment\n3.9
# 4                                         TikTok\n3.8
# 5                                     PIH Health\n3.6
# 6                        Mercury Insurance Group\n3.4
# 7                   Providence Health & Services\n3.4
# 8                              Quinn Company CAT\n3.3
# 9                                       AppleOne\n3.3
# 10                                      AppleOne\n3.3
# 11                              SCAN Health Plan\n3.2
# 12                             Molina Healthcare\n3.1
# 13                             Molina Healthcare\n3.1
# 14  SkillsetGroup - Professional Staffing Solution...
# 15                                NTT DATA, Inc.\n2.9
# 16                               Pacific Clinics\n2.9
# 17               Information Technology Partners\n2.8
# 18                                     Moveworks\n5.0
# 19                                        NVIDIA\n4.6
#
#                                 Sector  MAX(MaxSalary)  MAX(Rating)
# 0                    Business Services           113.0          5.0
# 1                    Business Services           113.0          4.6
# 2                            Insurance           113.0          4.1
# 3                                Media           113.0          3.9
# 4               Information Technology           113.0          3.8
# 5                          Health Care           113.0          3.6
# 6                            Insurance           113.0          3.4
# 7                          Health Care           113.0          3.4
# 8   Construction, Repair & Maintenance           113.0          3.3
# 9                    Business Services           113.0          3.3
# 10                   Business Services           113.0          3.3
# 11                           Insurance           113.0          3.2
# 12                           Insurance           113.0          3.1
# 13                           Insurance           113.0          3.1
# 14                   Business Services           113.0          2.9
# 15                  Accounting & Legal           113.0          2.9
# 16                         Health Care           113.0          2.9
# 17              Information Technology           113.0          2.8
# 18              Information Technology           110.0          5.0
# 19              Information Technology           110.0          4.6

# %% [markdown]
# ### 3. Sektor yang paling membutuhkan banyak Data Analyst

# %%
df_sektor_banyak_kebutuhan = """SELECT Sector, COUNT(*) AS Count
                            FROM data
                            GROUP BY Sector
                            ORDER BY count DESC
                            LIMIT 20"""
ps.sqldf(df_sektor_banyak_kebutuhan)
# Out:
#                                 Sector  Count
# 0               Information Technology    570
# 1                    Business Services    524
# 2                              Finance    169
# 3                          Health Care    151
# 4                            Education     52
# 5                            Insurance     51
# 6                   Accounting & Legal     43
# 7                                Media     42
# 8                        Manufacturing     40
# 9                               Retail     38
# 10                          Government     36
# 11           Biotech & Pharmaceuticals     33
# 12                          Non-Profit     26
# 13                 Aerospace & Defense     22
# 14          Transportation & Logistics     20
# 15  Construction, Repair & Maintenance     16
# 16                   Consumer Services     14
# 17        Oil, Gas, Energy & Utilities     13
# 18                         Real Estate     12
# 19                  Telecommunications     11

# %%
plt.figure(figsize=(15,7.5)) 
plt.xticks(rotation='vertical') 

color_blind_palette = ["#DC267F", "#785EF0", "#648FFF", "#FE6100", "#FFB000", "#E80E8D", "#2E8766", "#95ABAC", "#65B925", "#906A42", "#C4D537", "#344A52", "#6C6E06", "#1C4DD2", "#216E00", "#2E03E5", "#A94424", "#7F6EA9", "#9B8453", "#380721"]

plot_sektor_kebutuhan = sns.barplot(x=data['Sector'].value_counts().head(20).index,
                                  y=data['Sector'].value_counts().head(20).values, palette=color_blind_palette)

plt.xlabel('Sector', fontsize=12.5)
plt.ylabel('Count', rotation=0, ha='right', fontsize=12.5)
plt.figtext(.5,.9,"Sektor dengan Kebutuhan DA Terbanyak", fontsize=20, fontweight='bold', fontname='helvetica', ha='center') #formatted title

for patch in plot_sektor_kebutuhan.patches:
    plot_sektor_kebutuhan.annotate("%.0f" % patch.get_height(), (patch.get_x() + patch.get_width() / 2., patch.get_height()),
                 ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                 textcoords='offset points')

plt.show()

# %% [markdown]
# ### 4. Daftar Kota dengan pekerjaan Data Analyst yang paling banyak

# %%
df_city = """SELECT Location, COUNT(*) AS Job_Count
                FROM data
                GROUP BY Location
                ORDER BY Job_Count DESC
                LIMIT 20"""
ps.sqldf(df_city)
# Out:
#              Location  Job_Count
# 0        New York, NY        260
# 1         Chicago, IL        109
# 2   San Francisco, CA        101
# 3          Austin, TX         73
# 4       Charlotte, NC         65
# 5     Los Angeles, CA         64
# 6         Houston, TX         62
# 7       San Diego, CA         54
# 8          Dallas, TX         54
# 9    Philadelphia, PA         50
# 10         Denver, CO         44
# 11    San Antonio, TX         42
# 12       San Jose, CA         31
# 13        Phoenix, AZ         30
# 14    Jersey City, NJ         28
# 15         Irving, TX         26
# 16          Tempe, AZ         25
# 17       Columbus, OH         22
# 18        Seattle, WA         21
# 19          Plano, TX         20

# %%
plt.figure(figsize=(15,7.5))
plt.xticks(rotation='vertical')

color_blind_palette = ["#DC267F", "#785EF0", "#648FFF", "#FE6100", "#FFB000", "#E80E8D", "#2E8766", "#95ABAC", "#65B925", "#906A42", "#C4D537", "#344A52", "#6C6E06", "#1C4DD2", "#216E00", "#2E03E5", "#A94424", "#7F6EA9", "#9B8453", "#380721"]

plot_city = sns.barplot(x=data['Location'].value_counts().head(20).index,
                        y=data['Location'].value_counts().head(20).values, palette=color_blind_palette)
plt.xlabel('Location', fontsize=12.5)
plt.ylabel('Count', rotation=0, ha='right', fontsize=12.5)
plt.figtext(.5,.9,'Kota dengan DA Terbanyak', fontsize=20, fontweight='bold', fontname='helvetica', ha='center') #formatted title

for patch in plot_city.patches:
             plot_city.annotate("%.0f" % patch.get_height(), (patch.get_x() + patch.get_width() / 2., patch.get_height()),
                 ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                 textcoords='offset points')

plt.show()

# %% [markdown]
# ### 5. Mencari korelasi antara peringkat/rating perusahaan dengan gaji yang ditawarkan

# %%
corr_data = data
corr_data["AvgSalary"] = corr_data[['MinSalary', 'MaxSalary']].mean(axis=1) #membuat kolom avgsalary utk menghitung rata2 dari MinSalary & MaxSalary
corr_data["Rating"] = pd.to_numeric(corr_data.Rating, errors='coerce') #convert typedata int kolom rating ke typedata numeric
corr_data.corr()
# Out:
#              Rating  MinSalary  MaxSalary  AvgSalary
# Rating     1.000000   0.028126   0.028126   0.028126
# MinSalary  0.028126   1.000000   1.000000   1.000000
# MaxSalary  0.028126   1.000000   1.000000   1.000000
# AvgSalary  0.028126   1.000000   1.000000   1.000000

# %%
plt.figure(figsize=(20,15))
plt.figtext(.5, .9, "Salary and Rating", fontsize=20, fontweight='bold', fontname='Helvetica', ha='right') #formatted title
sns.heatmap(corr_data.corr(), annot=True,cmap="PiYG")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Dari plotted headmap, terlihat bahwa hampir tidak ada korelasi (nilainya sangat dekat dengan 0) antara gaji min/maks atau rata-rata dan peringkat.
